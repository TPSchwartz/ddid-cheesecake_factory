# %%
import pandas as pd
import matplotlib as plt
import re

# %%
exit_notes = pd.read_excel(r'C:\Users\David Chaniott\Documents\Nashville Software School\python\projects\ddid-cheesecake_factory\data/idea.xlsx', sheet_name = 'Exit Notes')
exit_notes
# Out:
#      POE  Child ID        DOB Notification Date Initial Eligibility Date  \
# 0     UC    471738 2019-02-28        2019-10-17               2019-10-29
# 1     FT    449030 2018-07-22        2018-11-07               2018-12-03
# 2     FT    463311 2017-07-09        2019-05-24               2019-06-19
# 3     FT    463313 2017-07-09        2019-05-24               2019-06-19
# 4     FT    469194 2017-08-31        2019-09-04               2019-10-02
# ...   ..       ...        ...               ...                      ...
# 5577  MD    491609 2018-12-22        2020-10-20               2020-10-30
# 5578  GN    491743 2018-06-05        2020-10-22               2020-11-05
# 5579  ET    491879 2019-04-24        2020-10-26               2020-11-02
# 5580  SC    492267 2018-06-01        2020-10-30               2020-11-17
# 5581  SW    492408 2020-08-06        2020-11-03               2020-11-17
#
#      Initial IFSP Date Latest IFSP Date  \
# 0           2019-10-31       2020-05-12
# ...

# %%
all_cases = pd.read_excel(r'C:\Users\David Chaniott\Documents\Nashville Software School\python\projects\ddid-cheesecake_factory\data/idea.xlsx', sheet_name = 'ECO with Exit20-21')
all_cases
# Out:
#      DISTRICT                                           CHILD_ID  \
# 0          ET                                             456849
# 1          ET                                             490916
# 2          ET                                             426757
# 3          ET                                             480611
# 4          ET                                             492863
# ...       ...                                                ...
# 8443      NaN                                                NaN
# 8444      NaN                                                NaN
# 8445      NaN                                                NaN
# 8446      NaN  Corrected Child ID 475887 impossible combinati...
# 8447      NaN  Corrected Child ID 486516 impossible combinati...
#
#      ECO_Entry_DATE ECO_Exit_DATE        DOB Initial IFSP Date  \
# 0        2019-04-24    2019-10-14 2017-11-14        2019-04-24
# ...

# %%
all_cases.shape
# Out:
# (8448, 13)

# %%
exit_notes.shape
# Out:
# (5582, 11)

# %% [markdown]
# for index, row in exit_notes.iterrows() :
#     text = exit_notes['Exit Note']
#     text.str.extract('No')

# %%
exit_notes['Exit Note'].str.slice(-5)
# Out:
# 0       ID-19
# 1       ly***
# 2       es.**
# 3       es.**
# 4       dule.
#         ...
# 5577      NaN
# 5578      NaN
# 5579      NaN
# 5580      NaN
# 5581      NaN
# Name: Exit Note, Length: 5582, dtype: object

# %%
text = exit_notes['Exit Note']
text
# Out:
# 0                 * No Exit ECO available due to COVID-19
# 1       ***family moving out of state March 2021, and ...
# 2       **Completed the transition planning conference...
# 3       **Completed the transition planning conference...
# 4       **Due to the impact of the COVID-19 pandemic a...
#                               ...
# 5577                                                  NaN
# 5578                                                  NaN
# 5579                                                  NaN
# 5580                                                  NaN
# 5581                                                  NaN
# Name: Exit Note, Length: 5582, dtype: object

# %%
re.search('\d{2}-\d{2}-\d{4}', text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\DAVIDC~1\AppData\Local\Temp/ipykernel_37556/2162650017.py in <module>
# ----> 1 re.search('\d{2}-\d{2}-\d{4}', text)
#
# C:\ProgramData\Anaconda3\lib\re.py in search(pattern, string, flags)
#     199     """Scan through string looking for a match to the pattern, returning
#     200     a Match object, or None if no match was found."""
# --> 201     return _compile(pattern, flags).search(string)
#     202
#     203 def sub(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
exit_notes['some_date'] = re.search('No', exit_notes.loc[0, 'Exit Note'])
exit_notes

# %%
exit_notes['new_date'] = exit_notes['Exit Note'].str.extract(r'(.*\d{2}-\d{2}-\d{4}.*)')

# %%
exit_notes['new_date'].value_counts()

# %%
exit_notes['reopened'] = exit_notes['Exit Note'].str.extract(r'(.*reopened.*)')

# %%
exit_notes['reopened'].value_counts()

# %%
exit_notes['slash_date'] = exit_notes['Exit Note'].str.extract(r'(.\d{2}\\\d{2}\\\d{4}.)')

# %%
exit_notes['slash_date'].value_counts()

# %% [raw]
# reopened_df = exit_notes

# %%
reopened_df['Exit Note'].str.findall('(\\d{2}/\\d{}2/\\d{4})')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\DAVIDC~1\AppData\Local\Temp/ipykernel_37556/3260623972.py in <module>
# ----> 1 reopened_df['Exit Note'].str.findall('(\\d{2}/\\d{}2/\\d{4})')
#
# NameError: name 'reopened_df' is not defined

# %%
exit_notes

# %%
# Alex's code to filter reopened


reopened_df = exit_notes_df[exit_notes_df['Exit Note'].str.contains('reopened', case=False, na=False)].reset_index(drop=True)
reopened_df = reopened_df.drop(columns=['POE', 'DOB', 'Notification Date', 'Initial Eligibility Date'])
reopened_df
